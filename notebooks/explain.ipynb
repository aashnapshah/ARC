# %%
import pandas as pd
import sys

sys.path.append('../')
from data.dicts.col_dict import *
from helpers.plots import *
plt.rcParams.update(rc)

def plot(df, target, cohort, group=None, max_vars=8, race_col='index', cov_col='cov', val='fraction', save_path=None):
    d = df[df["target"] == target]
    d['cov'] = d['cov'].str.replace('Circumference', 'Circ.')
    d['cov'] = d['cov'].str.replace(':Poverty', '')
    d['cov'] = d['cov'].str.replace('High School', 'HS')
    
    d = d[d["group"].isin(group)] if group else d

    # Nature Medicine-style tweaks
    fig, ax = plt.subplots(figsize=(9, 1.5), dpi=300, constrained_layout=True)

    # Sort for consistent plotting order
    d["cov"] = pd.Categorical(d["cov"], categories=list(d["cov"].unique()), ordered=True)
    for race, g in d.groupby(race_col, sort=False):
        g = g.head(max_vars) if max_vars is not None else g
        x, y = g['cov'], g[val]

        # Draw line and points prominently
        ax.plot(
            x, y,
            marker="o",
            # markersize=1,
            # linewidth=0.5,
            color=r_colors[race],
            label=str(race).title(),
            zorder=3,
            solid_capstyle="round",
        )
        if val == 'coef':
            # wider/thicker error bars for Nature style
            ax.errorbar(
                x, y, yerr=g['std_err'],
                fmt='none',
                ecolor='gray',
                # elinewidth=0.3,
                # capsize=0,
                # capthick=1,
                zorder=2,
                alpha=0.85
            )

        # Set ticks and grid
        ax.set_xticks(g["cov"].unique())
        ax.set_xticklabels(g["cov"].unique(), rotation=0, ha="right", rotation_mode='anchor')

    unit = 'mL' if val == 'coef' else '%'
    ax.set_ylabel(f"{target.upper()} Explained ({unit})", labelpad=7)
    ax.set_xlabel("")
    ax.tick_params(axis='y')
    ax.yaxis.grid(True, linestyle=':', alpha=0.6)
    ax.xaxis.grid(False)

    # # Remove chart spines for clean look:
    # for s in ['right', 'top']:
    #     ax.spines[s].set_visible(False)
    # # ax.spines['left'].set_linewidth(1.2)
    # # ax.spines['bottom'].set_linewidth(1.2)
    
    # Put legend outside, larger, Nature-style
    ax.legend(
        ncols=len(race_dict.keys()),
        loc="upper center",
        bbox_to_anchor=(0.5, 1.3),
        frameon=False,
    )
    ax.text(
        1.02, 0.5, cohort_dict[cohort],
        transform=ax.transAxes, rotation=-90,
        va="center", ha="left",
    )

    if save_path:
        plt.savefig(save_path, bbox_inches='tight', pad_inches=0.15, format='pdf', dpi=300)
    plt.show()
    return

cohorts = ['nh3', 'nh4', 'nh', 'ukb']
targets = ["fev1", "fvc"]
units = ['coef', 'frac']
output_types = ['reset', 'cont']
output_dir = '../results/explain/figures'
data_dir = '../results/explain/tables/processed'

for cohort in cohorts:
    df = pd.read_csv(f"{data_dir}/{cohort}_reset.csv").query("group in ['baseline', 'anthropometrics']")
    for t in targets:
        if t == "fev1":
            continue
        for unit in ['coef', 'fraction']:
            save_path = f"{output_dir}/{t}_{cohort}_{unit}.png"
            plot(df, t, cohort=cohort, val=unit, save_path=save_path)
# Out:
#    n_vars            group target  index                  cov   fraction  \
# 0       1         baseline   fev1  black             Baseline   0.000000
# 1       2  anthropometrics   fev1  black           Sit Height  14.391727
# 2       3  anthropometrics   fev1  black  Waist Circumference  20.186422
# 3       4  anthropometrics   fev1  black           Arm Length  19.278313
# 4       5  anthropometrics   fev1  black    Arm Circumference  20.462455
#
#      coef  std_err      t             p        mse
# 0 -499.94    29.35 -17.03  8.587584e-60  200705.79
# 1 -427.99    28.23 -15.16  1.568895e-48  147631.29
# 2 -399.02    28.39 -14.06  2.403532e-42  144978.65
# 3 -403.56    28.55 -14.14  9.003354e-43  144997.01
# 4 -397.64    28.82 -13.80  6.221557e-41  143423.60
# /tmp/ipykernel_1516294/1685889332.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['cov'] = d['cov'].str.replace('Circumference', 'Circ.')
# /tmp/ipykernel_1516294/1685889332.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['cov'] = d['cov'].str.replace(':Poverty', '')
# /tmp/ipykernel_1516294/1685889332.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['cov'] = d['cov'].str.replace('High School', 'HS')
# /tmp/ipykernel_1516294/1685889332.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["cov"] = pd.Categorical(d["cov"], categories=list(d["cov"].unique()), ordered=True)
# /tmp/ipykernel_1516294/1685889332.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['cov'] = d['cov'].str.replace('Circumference', 'Circ.')
# /tmp/ipykernel_1516294/1685889332.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['cov'] = d['cov'].str.replace(':Poverty', '')
# /tmp/ipykernel_1516294/1685889332.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['cov'] = d['cov'].str.replace('High School', 'HS')
# /tmp/ipykernel_1516294/1685889332.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["cov"] = pd.Categorical(d["cov"], categories=list(d["cov"].unique()), ordered=True)
