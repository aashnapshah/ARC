# %%
import pandas as pd
import sys

sys.path.append('../')
from data.dicts.col_dict import *
from helpers.plots import *
plt.rcParams.update(rc)

def plot_two_cohorts_unit(df_dict, cohorts, target, group=None, max_vars=8, race_col='index', cov_col='cov', val='coef', save_path=None, show_title=None):
    # 
    # If increasing hspace did not work, try forcibly increasing figure height,
    # or add dummy invisible axes between the real ones to hack the spacing.
    # Here, increase the figure height substantially and directly adjust axes positions. Disable all layout managers.
    fig, axes = plt.subplots(2, 1, figsize=(9, 3), dpi=300, constrained_layout=False)
    plt.subplots_adjust(hspace=0.05, wspace=0.02, top=1, bottom=0.0)  # further decreased vertical space (hspace) and adjusted top/bottom

    unit = 'mL' if val == 'coef' else '%'
    cohort_disps = [cohort_dict.get(c, c) for c in cohorts]

    # The main Y-label with a subtitle (super Y-label)
    fig.supylabel(f"{target.upper()} Explained ({unit})", x=0.01, y=0.5, va='center', ha='left')

    for idx, cohort in enumerate(cohorts):
        ax = axes[idx]
        d = df_dict[cohort]
        d = d[d["target"] == target].copy()

        d['cov'] = d['cov'].str.replace('Circumference', 'Circ.')
        d['cov'] = d['cov'].str.replace(':Poverty', '')
        d['cov'] = d['cov'].str.replace('High School', 'HS')
        d = d[d["group"].isin(group)] if group else d
        d["cov"] = pd.Categorical(d["cov"], categories=list(d["cov"].unique()), ordered=True)

        for race, g in d.groupby(race_col, sort=False):
            g = g.head(max_vars) if max_vars is not None else g
            x, y = g['cov'], g[val]
            ax.plot(
                x, y,
                marker="o",
                color=r_colors[race],
                label=str(race).title(),
                zorder=3,
                solid_capstyle="round"
            )
            if val == 'coef':
                ax.errorbar(
                    x, y, yerr=g['std_err'],
                    fmt='none',
                    ecolor='gray',
                    zorder=2,
                    alpha=0.85
                )

        # Remove the old y-label
        # ax.set_ylabel(f"{target.upper()} ({unit})", labelpad=7)
        ax.tick_params(axis='y')
        ax.yaxis.grid(True, linestyle=':', alpha=0.6)
        ax.xaxis.grid(False)
        # add the cohort name on the right side of the plot
        ax.text(1.02, 0.5, cohort_disps[idx], transform=ax.transAxes, ha='left', va='center', rotation=-90, fontweight='bold')
        if idx == 0:
            ax.legend(
                ncols=len(race_dict.keys()),
                loc="upper center",
                bbox_to_anchor=(0.5, 1.22),
                frameon=False,
            )
        ax.set_xticks(list(d["cov"].unique())[:max_vars])
        ax.set_xticklabels(list(d["cov"].unique())[:max_vars], rotation=0, ha="right", rotation_mode='anchor')
        ax.set_xlabel("")
        # For debugging, print current axes positions
        # print(f"Axes {idx} position:", ax.get_position())

    # Hack: forcibly increase the distance between subplots by moving axes manually
    box0 = axes[0].get_position()
    box1 = axes[1].get_position()
    # # Move top plot up, bottom plot further down
    axes[0].set_position([box0.x0, box0.y0 + 0.05, box0.width, box0.height])
    axes[1].set_position([box1.x0, box1.y0 - 0.05, box1.width, box1.height])

    if save_path:
        plt.savefig(save_path, bbox_inches='tight', pad_inches=0.20, format='pdf', dpi=300)
    plt.show()
    return

# --- Setup ---
cohorts = ['nh3', 'nh4', 'nh', 'ukb']
targets = ["fev1", "fvc"]
output_dir = '../results/explain/figures'
data_dir = '../results/explain/tables/processed'

# Read all data
df_dict = {
    c: pd.read_csv(f"{data_dir}/{c}_cont.csv")
    for c in cohorts
}

# Plot: Each plot has two cohorts per row (UKB+NH, NH3+NH4), for each outcome and each unit
vals = ['coef', 'fraction']
pairs = [(['ukb', 'nh'], ['UK BioBank', 'NHANES III-IV']), (['nh3', 'nh4'], ['NHANES III', 'NHANES IV'])]

for t in targets:
    for val in vals:
        for cohort_pair, cohort_disp_names in pairs:
            save_path = f"{output_dir}/{t}_{'_'.join(cohort_pair)}_{val}.pdf"
            plot_two_cohorts_unit(
                df_dict,
                cohort_pair,
                t,
                val=val,
                save_path=save_path,
                show_title=cohort_disp_names,
            )
